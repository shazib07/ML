# %% [markdown]
# <a href="https://colab.research.google.com/github/shazib07/ML/blob/main/1_Cats_vs_Dogs_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from fastai.vision.all import *
path = untar_data(URLs.PETS)

# %%
path.ls()
# Out:
# (#2) [Path('/root/.fastai/data/oxford-iiit-pet/annotations'),Path('/root/.fastai/data/oxford-iiit-pet/images')]

# %%
files = get_image_files(path/"images")
len(files)
# Out:
# 7390

# %%
files[0],files[3]
# Out:
# (Path('/root/.fastai/data/oxford-iiit-pet/images/Sphynx_148.jpg'),
#  Path('/root/.fastai/data/oxford-iiit-pet/images/beagle_188.jpg'))

# %%
def label_func(f): return f[0].isupper()

# %%
dls = ImageDataLoaders.from_name_func(path, files, label_func, item_tfms=Resize(224))

# %%
dls.show_batch()

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# ...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.153852</td>
#       <td>0.024844</td>
#       <td>0.008796</td>
#       <td>27:28</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.062054</td>
#       <td>0.018781</td>
#       <td>0.008119</td>
#       <td>36:58</td>
#     </tr>
#   </tbody>
# </table>

# %%
import ipywidgets as widgets
uploader = widgets.FileUpload()
uploader
# Out:
# FileUpload(value={}, description='Upload')

# %%
img = PILImage.create(uploader.data[0])

# %%
img
# Out:
# PILImage mode=RGB size=976x549

# %%
is_cat,_,probs = learn.predict(img)

# %%
print(f"is this a cat?: {is_cat}.")
print(f"Probability : {probs[1].item():.6f}")
# Out:
# is this a cat?: True.
# Probability : 1.000000
